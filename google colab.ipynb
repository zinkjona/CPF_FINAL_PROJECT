# %%
# import shutil
# import os
#
# if os.path.exists('CPF_FINAL_PROJECT'):
#     shutil.rmtree('CPF_FINAL_PROJECT')
#
# !git clone https://github.com/zinkjona/CPF_FINAL_PROJECT.git
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[16], line 5
#       2 import os
#       4 if os.path.exists('CPF_FINAL_PROJECT'):
# ----> 5     shutil.rmtree('CPF_FINAL_PROJECT')
#       7 get_ipython().system('git clone https://github.com/zinkjona/CPF_FINAL_PROJECT.git')
#
# File ~\Miniconda3\Lib\shutil.py:781, in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     779     # can't continue even if onexc hook returns
#     780     return
# --> 781 return _rmtree_unsafe(path, onexc)
#
# File ~\Miniconda3\Lib\shutil.py:635, in _rmtree_unsafe(path, onexc)
#     633             os.unlink(fullname)
#     634         except OSError as err:
# --> 635             onexc(os.unlink, fullname, err)
#     636 try:
#     637     os.rmdir(path)
#
# File ~\Miniconda3\Lib\shutil.py:633, in _rmtree_unsafe(path, onexc)
#     631 fullname = os.path.join(dirpath, name)
#     632 try:
# ...

# %%
# Out:
# fatal: destination path 'CPF_FINAL_PROJECT' already exists and is not an empty directory.

# %%
# !pip install catboost pandas
import pandas as pd

# %%
import sys
sys.path.append('/content/CPF_FINAL_PROJECT')
from MLFactor import Data

# %%
import sys
sys.path.append('/content/CPF_FINAL_PROJECT')
from MLFactor import Data
