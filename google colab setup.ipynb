# %%
import shutil
import os

if os.path.exists('CPF_FINAL_PROJECT'):
    shutil.rmtree('CPF_FINAL_PROJECT')

# !git clone https://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@github.com/zinkjona/CPF_FINAL_PROJECT.git

# %%
# !pip install catboost pandas
import pandas as pd

# %%
import sys
sys.path.append('/content/CPF_FINAL_PROJECT')
from ML_Multifactor import Data

# %%
pd.read_excel('/content/CPF_FINAL_PROJECT/data.xlsx')
